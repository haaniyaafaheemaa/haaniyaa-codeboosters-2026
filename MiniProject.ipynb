# %% [markdown]
# <a href="https://colab.research.google.com/github/haaniyaafaheemaa/haaniyaa-codeboosters-2026/blob/main/MiniProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("student_performance.csv")

# %%
print("Total Students: ", df.shape[0])
print("Total Columns: ", df.shape[1])
print("Departments: ", len(df.department.unique()))
print("Departments: ", df.department.value_counts())
# Out:
# Total Students:  30
# Total Columns:  13
# Departments:  4
# Departments:  department
# Computer Science    13
# Electronics          6
# Mechanical           6
# Civil                5
# Name: count, dtype: int64

# %%
print("Highest Math Score: ",df.math_score.max())
print("Lowest Math Score: ",df.math_score.min())
print("Average Math Score: ", df.math_score.mean().round(2))
print(f"Average Programming Score: {df.programming_score.mean():.2f}")
print("Average Attendance: ", df.attendance_percentage.mean().round(2), "%")
# Out:
# Highest Math Score:  95
# Lowest Math Score:  56
# Average Math Score:  76.07
# Average Programming Score: 67.60
# Average Attendance:  84.5 %

# %%
df['total_score'] = (df['programming_score'] + df['math_score'] + df['science_score'] + df['english_score'])
gender_scores = df.groupby('gender')['total_score'].mean().round(2)
print(gender_scores)
# Out:
# gender
# Female    310.67
# Male      280.67
# Name: total_score, dtype: float64

# %%
top5 = df.sort_values(by='total_score', ascending=False).head(5)
top5[['name', 'age', 'department','total_score']]
# Out:
#               name  age        department  total_score
# 9       Ananya Das   19  Computer Science          371
# 21     Tanvi Mehta   19  Computer Science          367
# 29  Akanksha Yadav   19  Computer Science          365
# 4       Arjun Nair   19  Computer Science          356
# 7      Divya Singh   19  Computer Science          356

# %%
print("\n")
low_att=df[df['attendance_percentage']<75][['name','department','attendance_percentage']]
if len(low_att)>0:
  print(low_att.to_string(index=False))
else:
  print("All students have attendance above 75%")

print("Report complete")
# Out:
#          name  department  attendance_percentage
#   Meera Joshi Electronics                     72
#  Rahul Mishra  Mechanical                     68
#  Manoj Pandey       Civil                     65
# Harish Pillai Electronics                     74
#  Sanjay Dubey       Civil                     70
# Sunita Pillai       Civil                     73
# Report complete
